# %% [markdown]
# # AI Check Example
#
# This notebook demonstrates how to use GigaChat API to check if text was generated by AI.

# %% [markdown]
# Import required libraries for authentication and GigaChat client.

# %%
import os
import getpass

from gigachat import GigaChat

# %% [markdown]
# Set up GigaChat credentials and scope. The input will be hidden for security.

# %%
if "GIGACHAT_CREDENTIALS" not in os.environ:
    os.environ["GIGACHAT_CREDENTIALS"] = getpass.getpass("GigaChat Credentials: ")

if "GIGACHAT_SCOPE" not in os.environ:
    os.environ["GIGACHAT_SCOPE"] = getpass.getpass("GigaChat Scope: ")
# Out:
# GigaChat Credentials:  ········
# GigaChat Scope:  ········

# %% [markdown]
# Initialize the GigaChat client and check if the provided text was generated by AI.

# %%
with GigaChat(verify_ssl_certs=False) as client:
    text = """Cats are cute and fluffy pets that belong to the cat family.
    They are known for their friendly nature, playfulness and soft fur.
    Cats can be of different breeds, each with its own unique characteristics.
    And this text was definitely not written by a neural network,
    because I'm writing it. I don't have much to say about cats,
    except that they are soft and fluffy, purring creatures.
    These animals have become popular due to their ability to lift people's spirits
    and create a cozy atmosphere in the home."""
    ai_result = client.check_ai(text, "GigaCheckDetection")
    print(ai_result)
# Out:
# category='ai' characters=505 tokens=112 ai_intervals=None
